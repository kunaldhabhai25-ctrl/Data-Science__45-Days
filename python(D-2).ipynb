# %% [markdown]
# FUNCTIONS IN PYTHON

# %%
#function
#example no. --> 1
def hello():
  print("hello world!")

hello()

print ("---------------")

#example no. --> 2
def hello2(a): #parameter
  print(a)

hello2(199) #argument

print ("---------------")

#example no. --> 3
def sum(num1,num2):
  print("the sum of ", num1 , "+" , num2 , "is :", num1 + num2)

sum(10,20)

print ("---------------")

#example no. --> 4
def power(num1,num2):
  print(num1**num2)

power(2,3)
power(num1=6,num2=3)

print ("---------------")

#example no. --> 5

def student(*a):
  print(a)
  print(type(a))

student(1 , 2 , 3 , 4 , 5 , 6 , 7 )
# Out:
# hello world!
# ---------------
# 199
# ---------------
# the sum of  10 + 20 is : 30
# ---------------
# 8
# 216
# ---------------
# (1, 2, 3, 4, 5, 6, 7)
# <class 'tuple'>

# %% [markdown]
# Question (1st)

# %%
def marks(a):
  for i in range(len(a)):
     print("marks of student is : " , a[i])

marks([10,20,30,40,50])
# Out:
# marks of student is :  10
# marks of student is :  20
# marks of student is :  30
# marks of student is :  40
# marks of student is :  50

# %% [markdown]
# Question (2nd)

# %%
def address(l):
  for i in l[0]:
    print(i)

address(["hello","yourname"])
# Out:
# h
# e
# l
# l
# o

# %%
#return statement in Python

def sum(num1,num2):

  return num1+num2

sum(20,22)
# Out:
# 42

# %%
#Lambda function in Python [lambda argument : expression]

add = lambda x: x
print(add(10))

print ("---------------")

add = lambda x,y : x + y
print(add(10,20))
# Out:
# 10
# ---------------
# 30

# %%
#Lambda function with star parameter

add = lambda *a : a[0]+a[1]
print(add(10,20))
# Out:
# 30

# %%
#list compression [expression for item in iterable]


#example
print("----------EXAMPLE----------")
L = [10,20,30,40,50,60]
print([L[i] for i in range(len(L))])


print("----------QUESTION----------")

#question
L = [10,20,[30,40,50,60]]
print([L[2][i] for i in range(len(L))])
# Out:
# ----------EXAMPLE----------
# [10, 20, 30, 40, 50, 60]
# ----------QUESTION----------
# [30, 40, 50]

# %%
#LIST
#initialization
L = [10,20,30,40]

print("length of list is : " , len(L))

print("---------------")

#append in list
L.append(50)
print("-----LIST AFTER APPENDING-----")
print(L)

#insert in list
L.insert(5,60)
print("-----LIST AFTER INSERTING-----")
print(L)

#remove in list
L.remove(60)
print("-----LIST AFTER REMOVING-----")
print(L)

print("-----LIST ELEMENTS-----")

#accessing individual elements of list
for i in range(len(L)):
  print("Element at index " , i , "is :" , L[i])
# Out:
# length of list is :  4
# ---------------
# -----LIST AFTER APPENDING-----
# [10, 20, 30, 40, 50]
# -----LIST AFTER INSERTING-----
# [10, 20, 30, 40, 50, 60]
# -----LIST AFTER REMOVING-----
# [10, 20, 30, 40, 50]
# -----LIST ELEMENTS-----
# Element at index  0 is : 10
# Element at index  1 is : 20
# Element at index  2 is : 30
# Element at index  3 is : 40
# Element at index  4 is : 50

# %% [markdown]
# Question No. --> 1 Of List

# %%
L = [10,20,30,{"name" : "kunal" , "address" : ["jaipur","kukas","hometown","friends home"]}]
print("---Without Loop---")
print(L[-1])
print("---Using Loop---")
for i in L[-1]["address"]:
  print(i, end = " ")
# Out:
# ---Without Loop---
# {'name': 'kunal', 'address': ['jaipur', 'kukas', 'hometown', 'friends home']}
# ---Using Loop---
# jaipur kukas hometown friends home

# %% [markdown]
# Question N0. --> 2 Of List

# %%
L = [10,20,30,[40,50,[60,70,80]]]

for i in range(2):
    print(L[3][i])
# Out:
# 40
# 50

# %%
#DICTIONARY IN PYTHON
dict = {"name" : "kunal" , "age" : "21"}
print(dict)

print(dict.keys())
print(dict.values())
for i in dict.keys():
  print("key = ", i)
  print("value = ", dict[i])
# Out:
# {'name': 'kunal', 'age': '21'}
# dict_keys(['name', 'age'])
# dict_values(['kunal', '21'])
# key =  name
# value =  kunal
# key =  age
# value =  21

# %% [markdown]
# Question Based on Dictionary

# %%
d ={
  "Message": "Number of Post office(s) found: 7",
  "Status": "Success",
  "PostOffice": [
    {
      "Name": "Ajmer Road",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Non-Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Industrial Estate (Jaipur)",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Non-Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Jaipur R.S.",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Khatipura Road",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Non-Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "P.W.D.Office",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Non-Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Raj Bhawan (Jaipur)",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Non-Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Station Road (Jaipur)",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Non-Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur City",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    }
  ]
}

print(d["Message"])
print(d["Status"])
for i in d["PostOffice"]:
  print(i["Name"])
  print(i["Taluk"])
  print(i["Circle"])
  print(i["District"])
  print(i["Division"])
  print(i["Region"])
  print(i["State"])
  print(i["Country"])
  print("\n")
# Out:
# Number of Post office(s) found: 7
# Success
# Ajmer Road
# Jaipur
# Jaipur
# Jaipur
# Jaipur City
# Jaipur HQ
# Rajasthan
# India
#
#
# Industrial Estate (Jaipur)
# Jaipur
# Jaipur
# Jaipur
# Jaipur City
# Jaipur HQ
# Rajasthan
# India
#
#
# Jaipur R.S.
# Jaipur
# Jaipur
# Jaipur
# Jaipur City
# Jaipur HQ
# Rajasthan
# India
#
#
# Khatipura Road
# Jaipur
# Jaipur
# Jaipur
# Jaipur City
# Jaipur HQ
# Rajasthan
# India
#
#
# P.W.D.Office
# Jaipur
# Jaipur
# Jaipur
# Jaipur City
# Jaipur HQ
# Rajasthan
# India
#
#
# Raj Bhawan (Jaipur)
# Jaipur
# Jaipur
# Jaipur
# Jaipur City
# Jaipur HQ
# Rajasthan
# India
#
#
# Station Road (Jaipur)
# Jaipur
# Jaipur
# Jaipur
# Jaipur City
# Jaipur HQ
# Rajasthan
# India
