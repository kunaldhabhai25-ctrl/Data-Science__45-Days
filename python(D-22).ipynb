# %% [markdown]
# Project Using SLR , MySql And Joblib :-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder , StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# !pip install pymysql cryptography
#pymysql connector
import pymysql
conn = pymysql.connect(host="13.220.156.88",user="mluser",database="ml_db",password="mlpass123")
print(conn)
query = "select avg_income,house_age,num_rooms,price from houses"
df = pd.read_sql(query,conn)
print("                      -Original Data-                      ")
print(df)


# data = {
#     "Name" : ["Kunal","Dheeraj","Yash","Ankita"],
#     "House_Age" : [20.2,2.5,3.0,4.0],
#     "Avg_Income" : [1000,200,300,400],
#     "Num_Rooms" : [3,4,5,1],
#     "Price" : [10000,7000,15000,11000]
# }
#data frame
# print("                      -Original Data-                      ")
# df = pd.DataFrame(data)
# print(df)
print('\n')
#handle missing values
# print("                      -Data After Data Cleaing-                      ")
# df.drop("Name" , axis = 1 , inplace = True)
# print(df)
# print('\n')
#feature scaling
print("                      -Data After Feature Scaling-                      ")
scaler = StandardScaler()
df[["avg_income","house_age","num_rooms","price" ]] = scaler.fit_transform(df[["avg_income","house_age","num_rooms","price"]])
print(df)
print('\n')
#split data
x = df[["avg_income","house_age","num_rooms","price"]]
y = df["price"]
#train test split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 ,random_state = 2)
print("                      -Data After Train Test Split-                      ")
print("_______________________X_Train_Test_______________________")
print(x_train)
print(x_test)
print("_______________________Y_Train_Test_______________________")
print(y_train)
print(y_test)
print('\n')
#model train
model = LinearRegression()
model.fit(x_train,y_train)
#model pridiction
avg_income = int(input("Enter Average Income : "))
house_age = float(input("Enter House Age : "))
num_rooms = int(input("Enter Number of Rooms : "))
new_data = {
    "avg_income" : [avg_inc],
    "house_age" : [h_age],
    "num_rooms" : [n_rooms]
}
new_df = pd.DataFrame(new_data)
new_df[["avg_income","house_age","num_rooms"]] = scaler.transform(new_df[["avg_inc","h_age","n_rooms"]])
predicted_price = model.predict(new_df)
print("_______________________Predicted Price_______________________")
print("Predicted Price : ", predicted_price[0])

#model dump
# !pip install joblib
import joblib
joblib.dump(model,"House_Model.joblib")
# Out:
# /tmp/ipykernel_8113/4161702955.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,conn)
# ...
#                       -Original Data-
#    avg_income  house_age  num_rooms    price
# 0        1000       10.2          3  10000.0
# 1         200        2.5          4   7000.0
# 2         300        3.0          5  15000.0
# 3         400        4.0          1  11000.0
#
#
#                       -Data After Feature Scaling-
#    avg_income  house_age  num_rooms     price
# 0    1.686761   1.705444  -0.169031 -0.262111
# 1   -0.883541  -0.784019   0.507093 -1.310556
# 2   -0.562254  -0.622366   1.183216  1.485297
# 3   -0.240966  -0.299059  -1.521278  0.087370
#
#
#                       -Data After Train Test Split-
# _______________________X_Train_Test_______________________
# ...
