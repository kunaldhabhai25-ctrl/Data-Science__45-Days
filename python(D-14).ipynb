# %% [markdown]
# #Sorting

# %%
import pandas as pd
dict = [
    {
      "name":"arun","gender":"Male","physics":88,"maths":87,"english":78
   },
    {"name":"rajesh","gender":"Male","physics":96,"maths":100,"english":95},
    {"name":"moorthy","gender":"Male","physics":89,"maths":90,"english":70},
    {"name":"raja","gender":"Male","physics":30,"maths":25,"english":40},
    {"name":"usha","gender":"Female","physics":67,"maths":45,"english":78},
    {"name":"priya","gender":"Female","physics":56,"maths":46,"english":78},
    {"name":"Sundar","gender":"Male","physics":12,"maths":67,"english":67},
    {"name":"Kavitha","gender":"Female","physics":78,"maths":71,"english":67},
    {"name":"Dinesh","gender":"Male","physics":56,"maths":45,"english":67},
    {"name":"Hema","gender":"Female","physics":71,"maths":90,"english":23},
    {"name":"Gowri","gender":"Female","physics":100,"maths":100,"english":100},
    {"name":"Ram","gender":"Male","physics":78,"maths":55,"english":47},
    {"name":"Murugan","gender":"Male","physics":34,"maths":89,"english":78},
    {"name":"Jenifer","gender":"Female","physics":67,"maths":88,"english":90}
]
print("----------Question----------")
df = pd.DataFrame(dict)
print(df)

print('\n')
print("_______________________________________________")
print('\n')
#sorting values (by default ascending)
df.sort_values("english" , inplace = True)
print("----------Ascending Order----------")
print(df)

print('\n')
print("_______________________________________________")
print('\n')

#sorting values in descending order
df.sort_values("maths" , ascending = False , inplace = True)
print("----------Descending Order----------")
print(df)
# Out:
# ----------Question----------
#        name  gender  physics  maths  english
# 0      arun    Male       88     87       78
# 1    rajesh    Male       96    100       95
# 2   moorthy    Male       89     90       70
# 3      raja    Male       30     25       40
# 4      usha  Female       67     45       78
# 5     priya  Female       56     46       78
# 6    Sundar    Male       12     67       67
# 7   Kavitha  Female       78     71       67
# 8    Dinesh    Male       56     45       67
# 9      Hema  Female       71     90       23
# 10    Gowri  Female      100    100      100
# 11      Ram    Male       78     55       47
# 12  Murugan    Male       34     89       78
# 13  Jenifer  Female       67     88       90
#
#
# _______________________________________________
#
#
# ----------Ascending Order----------
#        name  gender  physics  maths  english
# 9      Hema  Female       71     90       23
# 3      raja    Male       30     25       40
# 11      Ram    Male       78     55       47
# 7   Kavitha  Female       78     71       67
# 6    Sundar    Male       12     67       67
# 8    Dinesh    Male       56     45       67
# 2   moorthy    Male       89     90       70
# 5     priya  Female       56     46       78
# 0      arun    Male       88     87       78
# 4      usha  Female       67     45       78
# 12  Murugan    Male       34     89       78
# 13  Jenifer  Female       67     88       90
# 1    rajesh    Male       96    100       95
# 10    Gowri  Female      100    100      100
#
#
# _______________________________________________
#
#
# ----------Descending Order----------
#        name  gender  physics  maths  english
# 10    Gowri  Female      100    100      100
# 1    rajesh    Male       96    100       95
# 9      Hema  Female       71     90       23
# 2   moorthy    Male       89     90       70
# 12  Murugan    Male       34     89       78
# 13  Jenifer  Female       67     88       90
# 0      arun    Male       88     87       78
# 7   Kavitha  Female       78     71       67
# 6    Sundar    Male       12     67       67
# 11      Ram    Male       78     55       47
# 5     priya  Female       56     46       78
# 8    Dinesh    Male       56     45       67
# 4      usha  Female       67     45       78
# 3      raja    Male       30     25       40

# %% [markdown]
# #Alternate Methods For Sorting

# %%
#alternate methods
import pandas as pd
dict = [
    {
      "name":"arun","gender":"Male","physics":88,"maths":87,"english":78
   },
    {"name":"rajesh","gender":"Male","physics":96,"maths":100,"english":95},
    {"name":"moorthy","gender":"Male","physics":89,"maths":90,"english":70},
    {"name":"raja","gender":"Male","physics":30,"maths":25,"english":40},
    {"name":"usha","gender":"Female","physics":67,"maths":45,"english":78},
    {"name":"priya","gender":"Female","physics":56,"maths":46,"english":78},
    {"name":"Sundar","gender":"Male","physics":12,"maths":67,"english":67},
    {"name":"Kavitha","gender":"Female","physics":78,"maths":71,"english":67},
    {"name":"Dinesh","gender":"Male","physics":56,"maths":45,"english":67},
    {"name":"Hema","gender":"Female","physics":71,"maths":90,"english":23},
    {"name":"Gowri","gender":"Female","physics":100,"maths":100,"english":100},
    {"name":"Ram","gender":"Male","physics":78,"maths":55,"english":47},
    {"name":"Murugan","gender":"Male","physics":34,"maths":89,"english":78},
    {"name":"Jenifer","gender":"Female","physics":67,"maths":88,"english":90}
]
print("----------Question----------")
df = pd.DataFrame(dict)
print(df)

print('\n')
print("_______________________________________________")
print('\n')
#sorting values (by default ascending)
df.sort_values(by = ["english"] , inplace = True)
print("----------Ascending Order----------")
print(df)

print('\n')
print("_______________________________________________")
print('\n')

#sorting in descending order
df.sort_values(by = ["maths"] , ascending = False , inplace = True)
print("----------Descending Order----------")
print(df)


print('\n')
print("_______________________________________________")
print('\n')


#sorting 2 columns
df.sort_values(by = ["english" , "maths"] , ascending =[True , False])
print("----------Descending Order (Two Columns)----------")
print(df)

print('\n')
print("_______________________________________________")
print('\n')


#sorting by Names'
df["name"] = df["name"].str.upper()
df_s = df.sort_values(by = ["name"])
print("----------Ascending Order (Name)----------")
print(df_s)
# Out:
# ----------Question----------
#        name  gender  physics  maths  english
# 0      arun    Male       88     87       78
# 1    rajesh    Male       96    100       95
# 2   moorthy    Male       89     90       70
# 3      raja    Male       30     25       40
# 4      usha  Female       67     45       78
# 5     priya  Female       56     46       78
# 6    Sundar    Male       12     67       67
# 7   Kavitha  Female       78     71       67
# 8    Dinesh    Male       56     45       67
# 9      Hema  Female       71     90       23
# 10    Gowri  Female      100    100      100
# 11      Ram    Male       78     55       47
# 12  Murugan    Male       34     89       78
# 13  Jenifer  Female       67     88       90
#
#
# _______________________________________________
#
#
# ----------Ascending Order----------
#        name  gender  physics  maths  english
# 9      Hema  Female       71     90       23
# 3      raja    Male       30     25       40
# 11      Ram    Male       78     55       47
# 7   Kavitha  Female       78     71       67
# 6    Sundar    Male       12     67       67
# 8    Dinesh    Male       56     45       67
# 2   moorthy    Male       89     90       70
# 5     priya  Female       56     46       78
# 0      arun    Male       88     87       78
# 4      usha  Female       67     45       78
# 12  Murugan    Male       34     89       78
# 13  Jenifer  Female       67     88       90
# 1    rajesh    Male       96    100       95
# 10    Gowri  Female      100    100      100
#
#
# _______________________________________________
#
#
# ----------Descending Order----------
#        name  gender  physics  maths  english
# 10    Gowri  Female      100    100      100
# 1    rajesh    Male       96    100       95
# 9      Hema  Female       71     90       23
# 2   moorthy    Male       89     90       70
# 12  Murugan    Male       34     89       78
# 13  Jenifer  Female       67     88       90
# 0      arun    Male       88     87       78
# 7   Kavitha  Female       78     71       67
# 6    Sundar    Male       12     67       67
# 11      Ram    Male       78     55       47
# 5     priya  Female       56     46       78
# 8    Dinesh    Male       56     45       67
# 4      usha  Female       67     45       78
# 3      raja    Male       30     25       40
#
#
# _______________________________________________
#
#
# ----------Descending Order (Two Columns)----------
#        name  gender  physics  maths  english
# 10    Gowri  Female      100    100      100
# 1    rajesh    Male       96    100       95
# 9      Hema  Female       71     90       23
# 2   moorthy    Male       89     90       70
# 12  Murugan    Male       34     89       78
# 13  Jenifer  Female       67     88       90
# 0      arun    Male       88     87       78
# 7   Kavitha  Female       78     71       67
# 6    Sundar    Male       12     67       67
# 11      Ram    Male       78     55       47
# 5     priya  Female       56     46       78
# 8    Dinesh    Male       56     45       67
# 4      usha  Female       67     45       78
# 3      raja    Male       30     25       40
#
#
# _______________________________________________
#
#
# ----------Ascending Order (Name)----------
#        name  gender  physics  maths  english
# 0      ARUN    Male       88     87       78
# 8    DINESH    Male       56     45       67
# 10    GOWRI  Female      100    100      100
# 9      HEMA  Female       71     90       23
# 13  JENIFER  Female       67     88       90
# 7   KAVITHA  Female       78     71       67
# 2   MOORTHY    Male       89     90       70
# 12  MURUGAN    Male       34     89       78
# 5     PRIYA  Female       56     46       78
# 3      RAJA    Male       30     25       40
# 1    RAJESH    Male       96    100       95
# 11      RAM    Male       78     55       47
# 6    SUNDAR    Male       12     67       67
# 4      USHA  Female       67     45       78

# %% [markdown]
# Question

# %%
import pandas as pd
dict = [
    {
      "name":"arun","gender":"Male","physics":88,"maths":87,"english":78
   },
    {"name":"rajesh","gender":"Male","physics":96,"maths":100,"english":95},
    {"name":"moorthy","gender":"Male","physics":89,"maths":90,"english":70},
    {"name":"raja","gender":"Male","physics":30,"maths":25,"english":40},
    {"name":"usha","gender":"Female","physics":67,"maths":45,"english":78},
    {"name":"priya","gender":"Female","physics":56,"maths":46,"english":78},
    {"name":"Sundar","gender":"Male","physics":12,"maths":67,"english":67},
    {"name":"Kavitha","gender":"Female","physics":78,"maths":71,"english":67},
    {"name":"Dinesh","gender":"Male","physics":56,"maths":45,"english":67},
    {"name":"Hema","gender":"Female","physics":71,"maths":90,"english":23},
    {"name":"Gowri","gender":"Female","physics":100,"maths":100,"english":100},
    {"name":"Ram","gender":"Male","physics":78,"maths":55,"english":47},
    {"name":"Murugan","gender":"Male","physics":34,"maths":89,"english":78},
    {"name":"Jenifer","gender":"Female","physics":67,"maths":88,"english":90}
]
print("----------Question----------")
df = pd.DataFrame(dict)
print(df)

print('\n')
print("_______________________________________________")
print('\n')

#adding a column
print("----------Adding Column----------")
df["total"] = df["physics"] + df["maths"] + df["english"]
print(df)
print('\n')
print("_______________________________________________")
print('\n')
print("----------Adding Row----------")
df.loc[14] = ["kunal" , "Male" , 98 , 100 , 100 , 398 ]
print(df)
print('\n')
print("_______________________________________________")
print('\n')

#delete row and column
df_N = df.drop(index = 14).drop(columns = ["english"])
print("----------Deleting Row And Column----------")
print(df_N)
print('\n')
# Out:
# ----------Question----------
#        name  gender  physics  maths  english
# 0      arun    Male       88     87       78
# 1    rajesh    Male       96    100       95
# 2   moorthy    Male       89     90       70
# 3      raja    Male       30     25       40
# 4      usha  Female       67     45       78
# 5     priya  Female       56     46       78
# 6    Sundar    Male       12     67       67
# 7   Kavitha  Female       78     71       67
# 8    Dinesh    Male       56     45       67
# 9      Hema  Female       71     90       23
# 10    Gowri  Female      100    100      100
# 11      Ram    Male       78     55       47
# 12  Murugan    Male       34     89       78
# 13  Jenifer  Female       67     88       90
#
#
# _______________________________________________
#
#
# ----------Adding Column----------
#        name  gender  physics  maths  english  total
# 0      arun    Male       88     87       78    253
# 1    rajesh    Male       96    100       95    291
# 2   moorthy    Male       89     90       70    249
# 3      raja    Male       30     25       40     95
# 4      usha  Female       67     45       78    190
# 5     priya  Female       56     46       78    180
# 6    Sundar    Male       12     67       67    146
# 7   Kavitha  Female       78     71       67    216
# 8    Dinesh    Male       56     45       67    168
# 9      Hema  Female       71     90       23    184
# 10    Gowri  Female      100    100      100    300
# 11      Ram    Male       78     55       47    180
# 12  Murugan    Male       34     89       78    201
# 13  Jenifer  Female       67     88       90    245
#
#
# _______________________________________________
#
#
# ----------Adding Row----------
#        name  gender  physics  maths  english  total
# 0      arun    Male       88     87       78    253
# 1    rajesh    Male       96    100       95    291
# 2   moorthy    Male       89     90       70    249
# 3      raja    Male       30     25       40     95
# 4      usha  Female       67     45       78    190
# 5     priya  Female       56     46       78    180
# 6    Sundar    Male       12     67       67    146
# 7   Kavitha  Female       78     71       67    216
# 8    Dinesh    Male       56     45       67    168
# 9      Hema  Female       71     90       23    184
# 10    Gowri  Female      100    100      100    300
# 11      Ram    Male       78     55       47    180
# 12  Murugan    Male       34     89       78    201
# 13  Jenifer  Female       67     88       90    245
# 14    kunal    Male       98    100      100    398
#
#
# _______________________________________________
#
#
# ----------Deleting Row And Column----------
#        name  gender  physics  maths  total
# 0      arun    Male       88     87    253
# 1    rajesh    Male       96    100    291
# 2   moorthy    Male       89     90    249
# 3      raja    Male       30     25     95
# 4      usha  Female       67     45    190
# 5     priya  Female       56     46    180
# 6    Sundar    Male       12     67    146
# 7   Kavitha  Female       78     71    216
# 8    Dinesh    Male       56     45    168
# 9      Hema  Female       71     90    184
# 10    Gowri  Female      100    100    300
# 11      Ram    Male       78     55    180
# 12  Murugan    Male       34     89    201
# 13  Jenifer  Female       67     88    245
#
#
# _______________________________________________

# %%
#delete data from index no. 6 to 13
df.drop(df.index[6:15] , inplace = True)
print(df)
#add new column
df["date_of_join"] = ["2025-12-03","2025-03-30","2026-01-04","2025-12-09","2024-08-03","2025-11-03"]
print('\n')
print(df["date_of_join"].dtype)

print('\n')
#converting datatype
print("----------After Conversion Of DataType----------")
df["date_of_join"] = pd.to_datetime(df["date_of_join"])
print(df)
print('\n')
print(df["date_of_join"].dtype)
print('\n')
print("_______________________________________________")
print('\n')
print("----------Date Operations----------")


#date operation
df["date_of_join"].dt.year
df["date_of_join"].dt.month
df["date_of_join"].dt.day
df["date_of_join"].dt.day_name()
# 20 days
df["date_of_join"]+pd.to_timedelta(20,unit="D")
df["date_of_join"]+pd.to_timedelta("20 Days")
# Out:
#       name  gender  physics  maths  english  total date_of_join
# 0     arun    Male       88     87       78    253   2025-12-03
# 1   rajesh    Male       96    100       95    291   2025-03-30
# 2  moorthy    Male       89     90       70    249   2026-01-04
# 3     raja    Male       30     25       40     95   2025-12-09
# 4     usha  Female       67     45       78    190   2024-08-03
# 5    priya  Female       56     46       78    180   2025-11-03
#
#
# object
#
#
# ----------After Conversion Of DataType----------
#       name  gender  physics  maths  english  total date_of_join
# 0     arun    Male       88     87       78    253   2025-12-03
# 1   rajesh    Male       96    100       95    291   2025-03-30
# 2  moorthy    Male       89     90       70    249   2026-01-04
# 3     raja    Male       30     25       40     95   2025-12-09
# 4     usha  Female       67     45       78    190   2024-08-03
# 5    priya  Female       56     46       78    180   2025-11-03
#
#
# datetime64[ns]
#
#
# _______________________________________________
#
#
# ----------Date Operations----------
# 0   2025-12-23
# 1   2025-04-19
# 2   2026-01-24
# 3   2025-12-29
# 4   2024-08-23
# 5   2025-11-23
# Name: date_of_join, dtype: datetime64[ns]
