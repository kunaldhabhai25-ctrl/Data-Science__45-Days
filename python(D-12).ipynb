# %%
import pandas as pd
D = {
  "Name" : ["Kunal" , "Dheeraj" , "Yash" , "Praveen"] ,
  "Roll.No" : [12 , 13 , 14 , 15 ]
}

df = pd.DataFrame(D)
print(df)
print(type(df))
# Out:
#       Name  Roll.No
# 0    Kunal       12
# 1  Dheeraj       13
# 2     Yash       14
# 3  Praveen       15
# <class 'pandas.core.frame.DataFrame'>
